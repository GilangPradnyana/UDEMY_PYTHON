# %%
import pandas as pd
covid = pd.read_csv("Covid_19_data.csv")

# %%
covid.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %% [markdown]
# COVID-19 SMALL DATASET

# %% [markdown]
# We have taken a small dataset of COVID-19, just for our understanding purpose.

# %%
covid.isnull().count()
# Out:
# Date         321
# State        321
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
covid.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(covid.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Q.1 Show the number of Confirmed, Deaths and Recovered cases in each Region

# %%
covid.groupby("Region").sum().head(50)
# Out:
#                                                                        Date  \
# Region
# Afghanistan                                                       4/29/2020
# Albania                                                           4/29/2020
# Algeria                                                           4/29/2020
# Andorra                                                           4/29/2020
# Angola                                                            4/29/2020
# Antigua and Barbuda                                               4/29/2020
# Argentina                                                         4/29/2020
# Armenia                                                           4/29/2020
# Australia                 4/29/20204/29/20204/29/20204/29/20204/29/20204...
# Austria                                                           4/29/2020
# Azerbaijan                                                        4/29/2020
# ...

# %%
covid.groupby("Region")["Confirmed"].sum().sort_values(ascending=False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %%
covid.groupby("Region")[["Confirmed", "Recovered"]].sum()
# Out:
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %%
covid.groupby("Region")["Recovered"].sum().sort_values(ascending=True)
# Out:
# Region
# Papua New Guinea         0
# South Sudan              0
# MS Zaandam               0
# Yemen                    1
# Cabo Verde               2
#                      ...
# Iran                 73791
# Mainland China       77610
# Germany             120400
# US                  120720
# Spain               132929
# Name: Recovered, Length: 187, dtype: int64

# %%
covid.groupby("Region")["Recovered"].sum().sort_values(ascending=False)
# Out:
# Region
# Spain               132929
# US                  120720
# Germany             120400
# Mainland China       77610
# Iran                 73791
#                      ...
# Cabo Verde               2
# Yemen                    1
# South Sudan              0
# Papua New Guinea         0
# MS Zaandam               0
# Name: Recovered, Length: 187, dtype: int64

# %% [markdown]
# Q2) Remove all the records where Confirmed is Less Than 10

# %%
covid.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
virus = covid[~(covid.Confirmed > 10)]

# %%
virus
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 59   4/29/2020                               NaN                 Gambia
# 70   4/29/2020                               NaN               Holy See
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 156  4/29/2020                               NaN               Suriname
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# ...

# %% [markdown]
# Q.3) In Wich Region, maximum number of confirmed cases were recorder?

# %%
covid.groupby("Region").Deaths.sum().sort_values(ascending=False).head(20)
# Out:
# Region
# US                60967
# Italy             27682
# UK                26166
# Spain             24275
# France            24121
# Belgium            7501
# Germany            6467
# Iran               5957
# Brazil             5513
# Netherlands        4727
# Mainland China     4633
# Canada             3155
# Turkey             3081
# Sweden             2462
# Mexico             1732
# Switzerland        1716
# Ireland            1190
# India              1079
# Portugal            973
# Russia              972
# Name: Deaths, dtype: int64

# %% [markdown]
# Q.4) In wich Region, minimum number of Deaths cases were recorder?

# %%
covid.groupby("Region").Deaths.sum().sort_values().head(20)
# Out:
# Region
# Laos                        0
# Mongolia                    0
# Mozambique                  0
# Cambodia                    0
# Fiji                        0
# Namibia                     0
# Nepal                       0
# Madagascar                  0
# Macau                       0
# Papua New Guinea            0
# Rwanda                      0
# Saint Kitts and Nevis       0
# Bhutan                      0
# Dominica                    0
# Central African Republic    0
# Saint Lucia                 0
# Holy See                    0
# Sao Tome and Principe       0
# Yemen                       0
# Western Sahara              0
# Name: Deaths, dtype: int64

# %% [markdown]
# Q.5) How many Confirmed, Deaths & Recivered cases were reported from India till 29 April 2020

# %%
india = covid[covid.Region == "India"][["Confirmed", "Deaths", "Recovered"]]

# %% [markdown]
# Q. 6-A) Sort the entire data wrt No. of Confirmed in ascending Order

# %%
covid.sort_values(by=['Confirmed'], ascending=True)
# Out:
#           Date                         State          Region  Confirmed  \
# 285  4/29/2020                     Recovered              US          0
# 284  4/29/2020                     Recovered          Canada          0
# 203  4/29/2020  Diamond Princess cruise ship          Canada          0
# 305  4/29/2020                         Tibet  Mainland China          1
# 289  4/29/2020     Saint Pierre and Miquelon          France          1
# ..         ...                           ...             ...        ...
# 57   4/29/2020                           NaN          France     165093
# 168  4/29/2020                           NaN              UK     165221
# 80   4/29/2020                           NaN           Italy     203591
# 153  4/29/2020                           NaN           Spain     236899
# 265  4/29/2020                      New York              US     299691
#
#      Deaths  Recovered
# 285       0     120720
# 284       0      20327
# 203       1          0
# ...

# %% [markdown]
# Q. 6-B) Sort the entire daata wrt No. of Recovered Cases in descending order.

# %%
covid.sort_values(by=['Confirmed'], ascending=False)
# Out:
#           Date                         State          Region  Confirmed  \
# 265  4/29/2020                      New York              US     299691
# 153  4/29/2020                           NaN           Spain     236899
# 80   4/29/2020                           NaN           Italy     203591
# 168  4/29/2020                           NaN              UK     165221
# 57   4/29/2020                           NaN          France     165093
# ..         ...                           ...             ...        ...
# 305  4/29/2020                         Tibet  Mainland China          1
# 289  4/29/2020     Saint Pierre and Miquelon          France          1
# 285  4/29/2020                     Recovered              US          0
# 284  4/29/2020                     Recovered          Canada          0
# 203  4/29/2020  Diamond Princess cruise ship          Canada          0
#
#      Deaths  Recovered
# 265   23477          0
# 153   24275     132929
# 80    27682      71252
# ...
