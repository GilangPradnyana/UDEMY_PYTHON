# %% [markdown]
# IMPORTING MODULES

# %%
# High kevek operations on files and collection of files
import shutil
shutil.copyfile('source.txt', "destination.txt")
# Out:
# 'destination.txt'

# %%
# Data Serialization
import json
data = {'name': "Krish", 'age' : 25}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)

print(type(parsed_data))
# Out:
# {"name": "Krish", "age": 25}
# <class 'str'>
# <class 'dict'>

# %%
# CSV
import csv

with open("example.csv", mode='w', newline = '') as file:
  writter = csv.writer(file)
  writter.writerow(["name", 'age'])
  writter.writerow(['Krish', 32])


with open('example.csv', mode = 'r') as file :
  reader = csv.reader(file)
  for row in reader :
    print(row)
# Out:
# ['name', 'age']
# ['Krish', '32']

# %%
from datetime import datetime, timedelta

now = datetime.now()
print(now)

yesterday = now -timedelta(days=1)
print(yesterday)
# Out:
# 2026-07-31 21:11:47.805965
# 2026-07-30 21:11:47.805965

# %%
# time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1785503542.5950184
# 1785503544.5955927

# %%
# Regular expression
import re
pattern = r'\d+'
text = "There are 123 apples 456"
match = re.search(pattern, text)
print(match.group())
# Out:
# 123
