# %% [markdown]
# THE MAP() FUNCTION IN PYTHON
#
# The map() function applies a given functuin to all items in an input list (or any other iterable) and returns a map object (an iterator). This is parcticulary useful for transforming data in a list

# %%
def square(x):
  return x*x

square (4)
# Out:
# 16

# %%
numbers = [1,2,3,4,5,6]
  
map()
