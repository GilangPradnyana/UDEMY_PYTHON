# %%
# Encapsultation with getter and setter Methods
# Public, protected, private variable

class Person:
  def __init__(self,name,age):
    self.name = name 
    self.age = age

def get_name(person):
  return person.name

person = Person("Krish", 34)
get_name(person)
# Out:
# 'Krish'

# %%
# Encapsultation with getter and setter Methods
# Public, protected, private variable
# Protected Code

class Person:
  def __init__(self,name,age,gender):
    self.__name = name 
    self.__age = age
    self.gender = gender

def get_name(person):
  return person.__name

person = Person("Krish", 34, 'Male')
get_name(person)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 15
#      12   return person.__name
#      14 person = Person("Krish", 34, 'Male')
# ---> 15 get_name(person)
#
# Cell In[5], line 12, in get_name(person)
#      11 def get_name(person):
# ---> 12   return person.__name
#
# AttributeError: 'Person' object has no attribute '__name'

# %%
# Encapsultation with getter and setter Methods
# Public, protected, private variable
# Protected Code

class Person:
  def __init__(self,name,age,gender):
    self._name = name 
    self._age = age
    self.gender = gender

class Employee(Person):
  def __init__(self, name, age, gender):
    super().__init__(self, name, gender)

employee = Employee("Krish",34,"Male")
print(employee._name)

# %%
# Encapsulating with getter and setter
class Person:
  def __init__(self,name,age):
    self.__name = name
    self.__age = age

  # getter method for name
  def get_name(self):
    return self.__name
  # getter method for age
  def get_age(self):
    return self.__age
  # setter method for age
  def set_age(self, age):
    if age > 0:
      self.__age = age
    else :
      print("Age cannot be negative")

person = Person("Krish", 34)

# Access and modify private  variables using getter and setter
print(person.get_name())
print(person.get_age())

person.set_age(35)
print(person.get_age())

person.set_age(-5)
# Out:
# Krish
# 34
# 35
# Age cannot be negative
