# %% [markdown]
# # NumPy Quiz Notebook
#
# Work through the questions below. Each cell has a **question** and a **TODO** — fill in the code and run it.
#
# Solutions are at the very bottom of the notebook. Don't peek until you've tried! 😉

# %%
import numpy as np

# %% [markdown]
# ## Quiz 1: Creating Arrays
#
# **Q1.** Create a 1D array containing 5, 10, 15, 20, 25.

# %%
# TODO

# %% [markdown]
# **Q2.** Create an array of 5 zeros using `np.zeros`.

# %%
# TODO

# %% [markdown]
# **Q3.** Create an array of integers from 10 to 19 (inclusive) using `np.arange`.

# %%
# TODO

# %% [markdown]
# **Q4.** Create 4 evenly spaced numbers between 0 and 1 using `np.linspace`.

# %%
# TODO

# %% [markdown]
# ## Quiz 2: Shape & Reshape
#
# **Q5.** Reshape a 1D array of 1-9 into a 3x3 matrix.

# %%
# TODO

# %% [markdown]
# **Q6.** Print the `shape` of the matrix from Q5, then transpose it.

# %%
# TODO

# %% [markdown]
# ## Quiz 3: Math & Statistics
#
# **Q7.** Given `a = np.array([1,2,3])` and `b = np.array([4,5,6])`, compute:
# - a + b
# - b - a
# - a * b
# - a ** 2

# %%
# TODO

# %% [markdown]
# **Q8.** Given `scores = np.array([70, 85, 90, 60, 95])`, compute its mean, median, min, max, and sum.

# %%
# TODO

# %% [markdown]
# ## Quiz 4: Indexing & Slicing
#
# **Q9.** Given `m = np.arange(1, 10).reshape(3, 3)`:
# - get the first row
# - get the second column
# - get the element in row 2, column 2
# - get the last row

# %%
# TODO

# %% [markdown]
# **Q10.** From the same matrix, extract the top-left 2x2 block.

# %%
# TODO

# %% [markdown]
# ## Quiz 5: Boolean Masking
#
# **Q11.** From `nums = np.array([3, 8, 1, 9, 4, 7])`, select all values greater than 4.

# %%
# TODO

# %% [markdown]
# **Q12.** How many values in `nums` are even? (hint: `%` and `.sum()`)

# %%
# TODO

# %% [markdown]
# ## Quiz 6: Concatenate & Stack
#
# **Q13.** Concatenate `[1,2]` and `[3,4]` into one array.

# %%
# TODO

# %% [markdown]
# **Q14.** Stack `[1,2]` and `[3,4]` vertically (as rows) to make a 2x2 matrix.

# %%
# TODO

# %% [markdown]
# # Solutions
#
# > Scroll down only after attempting every question!

# %% [markdown]
# ### Q1 — Q4 Solutions
# ```python
# # Q1
# a1 = np.array([5, 10, 15, 20, 25])
#
# # Q2
# a2 = np.zeros(5)
#
# # Q3
# a3 = np.arange(10, 20)
#
# # Q4
# a4 = np.linspace(0, 1, 4)
# ```

# %% [markdown]
# ### Q5 — Q6 Solutions
# ```python
# # Q5
# m = np.arange(1, 10).reshape(3, 3)
#
# # Q6
# print(m.shape)
# print(m.T)
# ```

# %% [markdown]
# ### Q7 — Q8 Solutions
# ```python
# # Q7
# a = np.array([1, 2, 3])
# b = np.array([4, 5, 6])
# print(a + b, b - a, a * b, a ** 2)
#
# # Q8
# scores = np.array([70, 85, 90, 60, 95])
# print(scores.mean())
# print(np.median(scores))
# print(scores.min(), scores.max())
# print(scores.sum())
# ```

# %% [markdown]
# ### Q9 — Q10 Solutions
# ```python
# m = np.arange(1, 10).reshape(3, 3)
#
# # Q9
# print(m[0])        # first row
# print(m[:, 1])     # second column
# print(m[2, 2])     # row 2, col 2
# print(m[-1])       # last row
#
# # Q10
# print(m[0:2, 0:2])
# ```

# %% [markdown]
# ### Q11 — Q12 Solutions
# ```python
# nums = np.array([3, 8, 1, 9, 4, 7])
#
# # Q11
# print(nums[nums > 4])
#
# # Q12
# print((nums % 2 == 0).sum())
# ```

# %% [markdown]
# ### Q13 — Q14 Solutions
# ```python
# # Q13
# print(np.concatenate([np.array([1, 2]), np.array([3, 4])]))
#
# # Q14
# print(np.vstack([np.array([1, 2]), np.array([3, 4])]))
# ```
