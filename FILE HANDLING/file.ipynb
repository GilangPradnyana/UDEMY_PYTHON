# %%
# Read a whole file
with open('example.txt', 'r') as file :
  content = file.read()
  print(content)
# Out:
# Hello how are you?
# I am goof
# Krish is my name
# Welcome to the course

# %%
# Read a file line by line
with open('example.txt', 'r') as file :
  for line in file :
    print(line)
# Out:
# Hello how are you?
#
# I am good
#
# Krish is my name
#
# Welcome to the course

# %%
# Writting a file
with open('example.txt', 'w') as file :
  file.write('Hello World \n')
  file.write('This is a New Line \n')

# %%
# Add new line
with open('example.txt', 'a') as file :
  file.write("Hai this is Gilang\n")
  file.write("and im add a new line\n")

# %%
with open('example.txt', 'r') as file :
  for line in file :
    print(line)
# Out:
# Hello World
#
# This is a New Line
#
# Hai this is Gilang
#
# and im add a new line

# %%
# Writing a list of lines to a file
lines = ['First line \n', 'Seccond line\n', 'Third line\n']
with open('example.txt', 'a') as file :
  file.writelines(lines)

# %%
with open('example.txt', 'r') as file :
  for line in file :
    print(line)
# Out:
# Hello World
#
# This is a New Line
#
# Hai this is Gilang
#
# and im add a new line
#
# First line
#
# Seccond line
#
# Third line

# %%
# Binnary files
data = b'\x00\x01\x02\x03'
with open('example.bin', 'wb') as bfile :
  bfile.write(data)

# %%
with open('example.bin', 'rb') as bfile :
  print(bfile)
# Out:
# <_io.BufferedReader name='example.bin'>

# %%
# Read a content from a source text file and write to a destination text file
with open('example.txt', 'r') as source_file :
  content = source_file.read()

with open ('destination.txt', 'w') as destionation_files :
  destionation_files.write(content)

with open ('destination.txt', 'r') as readDes :
  content = readDes.read()
  print(content)
# Out:
# Hello World
# This is a New Line
# Hai this is Gilang
# and im add a new line
# First line
# Seccond line
# Third line

# %%
def count_text_file(param) :
  with open(param, 'r') as file :
    lines = file.readline()
    lines_count = len(lines)
    word_count = sum(len(line.split()) for line in lines)
    char_count = sum(len(line) for line in lines)
  return lines_count, word_count, char_count

file_paths = 'example.txt'
lines, words, characters = count_text_file(file_paths)

print(f"Lines : {lines}, Words : {words}, Characters : {characters}")
# Out:
# Lines : 13, Words : 10, Characters : 13
